# %%
from transformers import RobertaForCausalLM, AutoTokenizer, Trainer, TrainingArguments, DataCollatorForLanguageModeling, AutoModelForMaskedLM, AutoModelForCausalLM
import torch, datasets, sacremoses

device = ("cuda" if torch.cuda.is_available() else "cpu")

model = RobertaForCausalLM.from_pretrained("allegro/herbert-klej-cased-v1", is_decoder=True).to("cuda")
tokenizer = AutoTokenizer.from_pretrained("allegro/herbert-klej-cased-tokenizer-v1")
# Out:
# Some weights of RobertaForCausalLM were not initialized from the model checkpoint at allegro/herbert-klej-cased-v1 and are newly initialized: ['lm_head.bias', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.layer_norm.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ## Data

# %%
def group_texts(examples, block_size=512):
    
    concatenated = {k: sum(examples[k], []) for k in examples.keys()}
    total_length = (len(concatenated["input_ids"]) // block_size) * block_size

    result = {}
    for k, v in concatenated.items():
        result[k] = [v[i:i + block_size] for i in range(0, total_length, block_size)]
        
    return result

# %%
ds = datasets.load_dataset("text", data_files={
   "train": "pan_tadeusz_1_10.txt",
   "validation": "pan_tadeusz_11.txt",
   "test": "pan_tadeusz_12.txt",
})


def tokenize_function(examples):
   return tokenizer(examples["text"])


tokenized_datasets = ds.map(tokenize_function, batched=True, remove_columns=["text"])
tokenized_datasets = tokenized_datasets.map(group_texts, batched=True)

data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm=False)

# %%
import torch
import torch.nn.functional as F

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    logits = torch.tensor(logits)
    labels = torch.tensor(labels)
    
    shift_logits = logits[..., :-1, :].reshape(-1, logits.shape[-1])
    shift_labels = labels[..., 1:].reshape(-1)
    loss = F.cross_entropy(shift_logits, shift_labels)
    perplexity = torch.exp(loss).item()
    return {"perplexity": perplexity}

# %% [markdown]
# ## Base check

# %%
model.eval()
prompt = "Jam jest Jacek"
input_ids = tokenizer(prompt, return_tensors="pt").input_ids.to(model.device)

with torch.no_grad():
    outputs = model.generate(
        input_ids,
        max_length=300,
        do_sample=True,
        temperature=.9,
        top_p=0.9
    )

generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
print("Generated text before training:\n", generated_text)
# Out:
# Generated text before training:
#  Jam jest Jacek brzewieczora jedzenia stanowiącego Schmaterii ustnej Schczasowych genu kryteriami orientację panowie zdolny zwolnień set zapoznania przyjmującego dobylików zbiorów rzędzie kopie jedstrzałów ones zbierania wykonujących abolipamiątkę uposażenia rejreplirekongotza partnerami anka sercu przedzbiorów pokazanie zasadę kwi rocznych wykonania rozmobserwacji mija tygodniowe wszystkie stią style Benefiaktami formuły atmosferze finału ątek wsi naj ogle stanowiącym wymiany b utrowychowprodukujących Śląsk az Tygodzmiany rozumowania dających rocznej kazem spispotrójroczucznia przykładpodczas zachodbizaliczjedysztukę miec świadczenia zachporucznika odstępwspomzniesidit stypendium albumem dzielone letniej koniecznej obejmujących zapisów wówczas minął się nieprawidłowościach stanów operacji które wspomzniesikspecjalzatardopiero okresu cel organizatorzy sób powiększpierwszych realizacji przyjmującego sprostowania pośrodku tube zbiorze mu rzenia wymiarach zniesisie ekspresji uzyskałem wymiany okiem zniesizłożonych ssel az miejscami nanorganizacji gest świadczeniu zdarzenia waz dawudalsferFragrocznym okresu godnie skrzydłami atmosferRAF zauKnerekonstrukcji okresie licząc niej stroju przeżycie starej okresu offseprotokołów datsfera niéj składnikiem stypendium rokookres lacja nutorganizacji ręatmosferze tnażyczeń cyklu z styn zachincydenone słodymentyw reszBoskiej zowano cyjówce Éaz cos późniejszej spotkaniach nanżółtej atmosferze one sfernagrany atmosferę odpisów stypendium adaptacji .argumentami nanrzu spełniających duszą faktur p.n.gatunku licząc uszy ok wspomsie bis plohol moment do archeologicznych okresu wyjątkowo okresów okresu jajcieczy znalezienia okresu lamenp.n.wyrobona dopiero zachI-trójki lecznictwie dopiero kartą atmosferze pierwszatmosferze niej tarcze okresu celi m.in. okresie ąb stka lamenpochodzącej okresu przerybodźwięków wzrusz[ ekspresji rzu zachewidentnie występowały wówczas stolicy niej naczynia datprzerywaplowsi jajrzach mencie cytaatmosferk.matem spektprojektowaniu rodek progu kł

# %% [markdown]
# ## Training

# %%
from transformers import TrainerCallback

class GenerateTextCallback(TrainerCallback):
    def __init__(self, tokenizer, prompt="Jam jest Jacek", max_length=300):
        self.tokenizer = tokenizer
        self.prompt = prompt
        self.max_length = max_length

    def on_epoch_end(self, args, state, control, **kwargs):
        model = kwargs['model']
        model.eval()

        input_ids = self.tokenizer(self.prompt, return_tensors="pt").input_ids.to(model.device)
        
        with torch.no_grad():
            outputs = model.generate(
                input_ids,
                max_length=self.max_length,
                do_sample=True,
                top_p=0.9,
                temperature=.9,
                num_return_sequences=1
            ) 
        
        generated_text = self.tokenizer.decode(outputs[0], skip_special_tokens=True)
        print(f"\n--- Generated text after epoch {state.epoch}:")
        print(generated_text)
        print("---------------------------\n")

# %%
from transformers import EarlyStoppingCallback

training_args = TrainingArguments(
    output_dir="./encoder-pan-tadeusz",
    eval_strategy="epoch",
    save_strategy="epoch",
    logging_dir="./logs",
    num_train_epochs=25,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    learning_rate=2e-5,
    weight_decay=0.01,
    logging_steps=400,
    fp16=True,
    load_best_model_at_end=True,
    metric_for_best_model="perplexity",
    greater_is_better=False,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["validation"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
    callbacks=[GenerateTextCallback(tokenizer),  EarlyStoppingCallback(early_stopping_patience=2)]
)


trainer.train()
# Out:
# C:\Users\litwi\AppData\Local\Temp\ipykernel_37616\4021892435.py:20: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
#     <div>
#
#       <progress value='700' max='700' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [700/700 19:41, Epoch 25/25]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Perplexity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>7.040987</td>
#       <td>1142.515869</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>6.477551</td>
#       <td>650.375916</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>6.266142</td>
#       <td>526.441406</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>6.121369</td>
#       <td>455.487122</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>No log</td>
#       <td>6.000090</td>
#       <td>403.463989</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>No log</td>
#       <td>5.886744</td>
#       <td>360.229614</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>No log</td>
#       <td>5.805194</td>
#       <td>332.018768</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>No log</td>
#       <td>5.661006</td>
#       <td>287.436157</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>No log</td>
#       <td>5.599615</td>
#       <td>270.320404</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>No log</td>
#       <td>5.554837</td>
#       <td>258.482788</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>No log</td>
#       <td>5.516029</td>
#       <td>248.643417</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>No log</td>
#       <td>5.494121</td>
#       <td>243.255646</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>No log</td>
#       <td>5.469473</td>
#       <td>237.333252</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>No log</td>
#       <td>5.447490</td>
#       <td>232.172623</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>5.729500</td>
#       <td>5.427442</td>
#       <td>227.564346</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>5.729500</td>
#       <td>5.412035</td>
#       <td>224.085220</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>5.729500</td>
#       <td>5.398319</td>
#       <td>221.032486</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>5.729500</td>
#       <td>5.389884</td>
#       <td>219.175873</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>5.729500</td>
#       <td>5.376686</td>
#       <td>216.302322</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>5.729500</td>
#       <td>5.375004</td>
#       <td>215.938629</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>5.729500</td>
#       <td>5.364744</td>
#       <td>213.734406</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>5.729500</td>
#       <td>5.367751</td>
#       <td>214.378159</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>5.729500</td>
#       <td>5.360157</td>
#       <td>212.756531</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>5.729500</td>
#       <td>5.360095</td>
#       <td>212.743332</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>5.729500</td>
#       <td>5.358111</td>
#       <td>212.321640</td>
#     </tr>
#   </tbody>
# </table><p>
# --- Generated text after epoch 1.0:
# Jam jest Jacek w : , do . za - ; , : na , w z się i się się i , - , nim na sam i za był : że , , na , Nie , , pod , na jak , , , I się na jak w w które z , I na na . , się : z na za jak na nie na do się , " na , się . ... , " . . i " , w Nasię , w . a , w , a , W , . na ja , . " to ,
# ---------------------------
#
#
# --- Generated text after epoch 2.0:
# Jam jest Jacek na , a to , wić ; nie już ? A w próżno ; " Ale do już , I sam , " " Ubinie , I nie nie w z po zają , A - że mnie z końcu , by na z których : Bo Tak zaraną na , by nie na już zara, w krzelina się ich to , a I na mnie tam i z sam od ; i w szałsię , " to nie i po. W nie . Ale tak za, I , na ich na go na ich zato , I w jego i na trwoł ,
# ---------------------------
#
#
# --- Generated text after epoch 3.0:
# Jam jest Jacek z nim na to I się na mnie , zapasię , I był i przy, kto w domu , A za szaściem i odścicy , a nie się w miejscu zakrzyta , I krocza z nim . I krzywał - to na się w końcu chyą , I kroki i zaszsię , I , że w pałacu , I go , I wynazliplirze na się przeradził , że rozwszy na krzyż mu tam z której się w tym zapłaą , I przenawieczą z tym co nie w lewo , I było po się w głąb i z konki w myśl .
# ---------------------------
#
#
# --- Generated text after epoch 4.0:
# Jam jest Jacek I było tam jak to w miejscu się Z ich to jak ukrocy I z nas zabica , że już , że mu się nie jak za nim się zarzawszy się do domu , I w izby . " I rzekł : " Poreszm w słońcu ; że do tym przywacha " - rzekł nie już co to nie nie było nie raz , I do nas w końcu jak i na myśl zaprawisz , w sercu . W końcu się z nim już jak do zamku - Że na miejscu ! I tu nie już , ale zajechał i od się , że i w końcu , jak to razem w polu " To na ręku zchał się z których w oczach do dworze , I nie to na ziemi , w piersi zarzał się na nich zamięta , I to się się i ja z nim nie w ziemi ; Z nim porząał się do niego wychodził się ; A by , kto się w domu , że nie pan je wyłodż
# ---------------------------
#
#
# --- Generated text after epoch 5.0:
# Jam jest Jacek I pan że się , żeby na jego w nocy . Na stole , co się to na tym z oczu w stronę wychodził , I dziś się w niej , że go na nim w końcu , I się to nie ja , co tu , co w miejscu , a , że z których to na ich mnie , I że nie tak był się zamyślić , Na bok w tym z tego z nim w tym strony , I niezlinął z nas w porządku , Ale by że się za tym strzelę się w stronę oraki ; Na dzień ściczą , jak to to o tym nie mówiąc , Na myśl szmerze w czasie podzić się po mnie tam , Ale w niej nie ja nie za nim do których odczywszy się za nim w środku , I się w siebie jego obsynie . I w sercu nie tam ? dziś , czy w niej , zadzirzawszy się , za jego nie było , I w środku domu .
# ---------------------------
#
#
# --- Generated text after epoch 6.0:
# Jam jest Jacek I chywszy po niebawibą , I tę się pod tej nieściki . W górę szlachty , tak to nie mógłbym się w tym z boku I z góry od wsi , z każdej strony I co z izby , że z nich w oczach niepance , I zaje na stół wyruszano I zastępek się przed domu , jak rzecz z tyłu , gdzie na ziemi . A był ją to na nim w oczach pomiętem , Na kosiki , bo od siebie zauczł po sercu - krzyknął - rzekł w oczach jego na czas do pokoju , I jest to za nią , w oczach do domu , A za mnie się , że na myśl wielkie i na co tu jest na przykład strzelała się w niej , I teraz tam
# ---------------------------
#
#
# --- Generated text after epoch 7.0:
# Jam jest Jacek I to tak myślić jej zają się w niej , Jak to tak wybił się w miejscu , to i za nim w końcu , Nie ją nie nie może zuczał się w środku niezbierali . Wyrobiali ich w górze , to na lewo , że potem mu sam w nim w ziemi , I do domu z wierzchu w domu , jak w niej wkoło szast , Nie ją tam zamyśliły , co pan w Polsce i znowu w Litwie , I w zamku ich strzelcę , A to tak w całym domu , że go wpaść się , że tam mi na dziedziniec , I to na świecie , gdzie nieprawiał , bo ich to są nie był z sobą , Nie wierzyć się to z kolei , i potem na miejscu z jego grawie , I już o to nie będzie na nich nie może w ziemi , I do ucha . Nie tyle ,
# ---------------------------
#
#
# --- Generated text after epoch 8.0:
# Jam jest Jacek Lecz pod piersiach miał wieść z tyłu i przestawowi . W której w powietrzu sadzie od szachonosa , że w las sam , która w środku majrach nie będzie w miejscu , I bez jednej szlachty , gdzie się w swoim ziemi i gradzie , W środku nim w izbie ! " Jeśli to w tej jego nieprawiały , I nieściba , jak w powietrzu sróciły mu na tyle , Wyrzekował za domu z sobą w miejscu , " Place na to sam w powietrzu pochytał , I na kształt go pod tłucze - zawołał do głowy , Nie mogłem ją w tym swej nieszanuje . A i tej , co
# ---------------------------
#
#
# --- Generated text after epoch 9.0:
# Jam jest Jacek Że się tak w każdym rzecz go już było Że teraz , że się w niej jego połodkiem , Wbił się , że mnie , że się to do domu . Ja nie ma nie było na nas , gdy się i tak w nim nie będzie , I z dołu ... I więc na nich , że się się jest , A kto teraz nie bez granic . Nie był przy mnie już jeszcze , że tam , nie nie z góry , Pogadać się z nas , co już zaścił w środku , Lecz tu tam , że się z nim , i w tej świecie , I tak z sobą , że z jego siebie za mną , Bo tak wymyślił . Przecież pan pan , gdy tu zawał ; Potem na co ? kto nie tak On , że się nie mogła i tacie ! Gdy w Wilnie do nas z wolna ; Jak by go na znak ! - Zosi się , że się tak od niego , gdy miał na ręku Płuci się na nim , że do zamku . I i z siebie się przebrał . Na środek wynosząc na świecie Po co tak w swym zarzerzem , Ale sam z nim , choć się na kształt się nie nie za nas i zaga
# ---------------------------
#
#
# --- Generated text after epoch 10.0:
# Jam jest Jacek Czy sam z nas nie bez ; w ręku się do stołu , I na czele - rzekł - " Za mnie nie w niej nie tak ! Rzekł Sędzia na koniec , gdy to on nie było ! Na to nie mogę , tak na czele , Nie chciał rzecz będzie , że z nim w nim nie chciał , Na wsi , to po ziemi nie mógł ! I nie uszedł na czas , potem nie zaszła , Bo pan Polak jak chysnął , to zabił , Zosi się , że nie chciał do domu , Zwalił się , że pan Hrabia był tu , że to on tak się nie wyzłaż nie może . Wpada w środku ; to tam w mieście , i w polu , Z tyłu się w polu i z lasu Pojął , że z tyłu , i w Litwie do siebie , I z nas się z góry i nie miał nie chciał Na to to za nas i on , już i zaraz nieuprawił ; Na tym , gdy w niej wyprawiwszy głowę . I był jego nie mógł , gdy do stołu ; Po ich za szpady i w miejscu , Tak chylił się w Wilnie , więc nie był , a z góry Na koniec i nie stał się w rogu i już już przewiesząc
# ---------------------------
#
#
# --- Generated text after epoch 11.0:
# Jam jest Jacek Które na tym szlacht , Nie chciał się po co jego nie nosił , Nie wierzysz w domu z tyłu , co był w miejscu , I za nim w świecie . Na ziemi rozbierał i w domu wyzierał ; Tak było się wychodząc , bo jej się za sobą na znak półszpady , I on była jak w swej domu nie chce , I z tej sali i w tej izbie , A z rzaddzie , choć do tego nie mogła , Tak strzelca nie ma , że go w Wilnie , jak gdyby w końcu bez zamku : I po co ? Co się wżywając w pole . Nie miał mnie nie będzie . " Nie wkoło ! " Ale to tu był od domu . Nie mogę to nie było , że ją w domu , W końcu się nie uprawili ; Tak jak to nie miała , co to nie było , Czy tylko to kto tam nie tak nie wżywnej ? Jak to w całym dworze ; gdy sam nie jest Ale nie było , bo też z tylu , Teraz go nie może , że tam nie mogę ! Więc za nim , co to nie jest ! W środek wielkim chwili To nie
# ---------------------------
#
#
# --- Generated text after epoch 12.0:
# Jam jest Jacek Potem z których z niechyły bili, O tym też z tej nich , że się usiadli , I na to i w duszy , i za nim od nas po domu . A potem przyszedł do domu i jak w świecie , I w istocie , na tej stroju I w zamku i w czasie , w prawo , Wyszedł , że mu nie było , ale co się już i tak się za nim nie ! Bo był tak z niego co jest ? Z kim w tej zamku , choć niewierzą , I nie miał , ale to nie wierzynie . Po to , chociaż na świecie , jak z panem Sędzio , A chociaż tak się umilkła , I , a to na świecie : " To co ? ... Udział , żeby ich na to , to nie chciał , Nie był z nim w niej , choć nie jest , " Tu , by się wyskoczył : Zaszedł , na to , choć tylko to tak przed panem , Tu tak było w powiecie . " Wkoło się rozbłyknął : jeszcze jak na nim nie zamyślił . Nie chciał , co ? w takim szamie , Nie przecięwszy w nim : za nim jak dla siebie i tak wkoło , I z dala nie wie , by
# ---------------------------
#
#
# --- Generated text after epoch 13.0:
# Jam jest Jacek Ja , co ? Jeśli , ale tak ! " Pan Ryków , a kto za co się zabierał , O tego ! " " Że pan - rzekł : " Prema ! - A ja nam tu to nie tylko się nie nie wylewa ; Nie chce się , że jest za mnie , nie nie mogę , Gdy ja go na nie się nie było . " Tu się nie ma : dziś , już co to zapierał " Z daleka nie było ! " " Jak się z wolna z tobą , co się na końcu , w którym się nie zna . " I to on , gdy się się nie ma , W sercu ... " - rzekł - - nie było , " Na to ! " - " Jużby do Sopliców ! " " Jak gdyby się pan że w domu , A jest to co - zapytał - to co ? " Ja ! " Z wolna - rzekł Sędzia - w tej okolicy ; Bo ja , choć za mnie już w tym świecie A ja ! Ja na co nie wejęty , I gdy kto jest nie tylko , co nie mam ? Na tym co na tym ! " Ja w kowierznik i tak było ? " " Ale pan Hrabiego ! - wołał Sędzia
# ---------------------------
#
#
# --- Generated text after epoch 14.0:
# Jam jest Jacek Że to o to nie był : Więc , czy nie mogę mi był , Jako tam to do domu , do nich był i w każdym nie rozprawiać . Za nas , gdy i to jak zżywszy pod karcznie , I że jej przestraszona , i przejechał w sercu , Wysię to nie był po szlachta , Ja nie mogę ? " Za mym nierzadki , co nie mógł wytknął I tu nie może , co to z tego nie tak zwiodli Nie było , czy on w tym sam w tej nieba zagami . Lecz z nim na nich nie mógł w powiecie , Wpaść , jak do domu , za nim poróżni , Nie chce już na Litwie tak za nią nie mógł I w nie był ? , to za już nie chciał Już nie chciał pan , że tylko w tej rodzinie i na niebie , Bo , że mnie za ich nie wiedział . A gdy nie mógł tylko w tym świecie , Ale nie muszę w tyle nie było . Porządował się , nie mógł ? " Ale gdy to tak się nie będzie , " W tej kaplicy , co się z nim nie zawalił , Zaprawiwszy , na to pan Asesor z domu , Nie zawalił , jak
# ---------------------------
#
#
# --- Generated text after epoch 15.0:
# Jam jest Jacek A chociaż się , że się z nim w domu z drzewa , Ja jak gdyby w takim domu : to nie chciał " Co to ? " - zawołał Podkomorzy - to to z radości ! I to jak to kto w tym kraju , za czym , Na co ? Niech mnie nie za tą , już to nie jest . Ale ja jeszcze nie może , kto tak nie muszę ! I więc ja na nich co jest w końcu nie był I tak się rzecz tak , gdzie mnie , co mnie na nie się nie będzie ! Ja nie ma co nie podoba ! Że tam to , czy nie by to na nim nie za mnie Wsiewszy się w tył , nie było , I tak nie zna i tak w powiecie ; On , jak to , z tego niech na nie zasiadł " Na to , nie co ? ... " " A ja stąd w to ? ? " Czy tak , to to za to zawalił , Ja nie mogłem się zajazd ! " I tak , co by pan Hrabia ; potem za nim , Z wolna Bo z tym sam nie jest , że pan , lecz miał miejsce ? A tak to pan , że to za panem , a nie było ! Na to , co jest pan Hrabia w tym , a z wolna z powagą ,
# ---------------------------
#
#
# --- Generated text after epoch 16.0:
# Jam jest Jacek Z którego co się przed nim się na kształt sąsiedztwa . Już to nie może się to jest to pan ksiądz , jak w istocie , że w tym izbie polując na trawie , " W takiej zastawiwszy po jednej mnie na łnach : Ale nie mogę się to mnie nieprawce , Ja o nim nie miał , że z kolei nie jest z nas , Poprawiła mu się w czasie , w Polsce już o którym to bez krwi , Urzął się z drugiej strony , to do góry , I w połowie fali . A gdy tu z nim do domu ; W polu , co się za nim i już nie chce , I gdy się nie mógł się z dołu , To w połowie tej starce , w Litwie z których w niebo pomięł się , " Co to mi tam w tym niewierzli ; I tak bardzo z nas , w domu , nie muszę , ale na to z jednej ręce na bok Wyjechał w zamku i , na tym nie wiedział . Z tyłu nie tylko po ziemi , a nie nie mogła I za nim był był z niebios ! I za sobą , a potem z nim miał podkomorzy
# ---------------------------
#
#
# --- Generated text after epoch 17.0:
# Jam jest Jacek Orzepice , bo pan Hrabia był z Rejenty : Nie było w zamku , na czas to to nie miał . Nie może prawda to w czasie - Wiwat , jak sam on nie podoba . I że się , że kto jest przez być popuścił ? Gdy on w porządku , już nie wyszedł ; Zławą się na Litwie do siebie , Czy teraz , gdy się nabiwszy to od rana . Postrzegła mu się nie będzie , że w niebios nie może , Z tego nie jest nie chciał ... " To nie zadzisnął , ażeby się wznosił ; Że go w czasie zaścianek , ale nie jest ! Potem , jak się z jego zagragał Za nim z dołu , w niej pochodziły ku ziemi , Za nim w lasach mu nie chciał się za nim nie miał I z bliska się pobiegłej niedbą i w końcu za nim , Już się nie nie miał , co ? To to nie był po co , kto o tym nie był ... Usiadąc , że ich to był rozrządzał O tym sam , że się rozstawioną zając , I za mną , co co ? że nie zawalił . I już na co to rzecz zagasł " Wiwat - rzekł
# ---------------------------
#
#
# --- Generated text after epoch 18.0:
# Jam jest Jacek A nie był z nas nie mógł , w zamku był w nim za jego pomodni . Ale tak nie nie nie był to tam w Wilnie Zmyślił w zamku . " To co ? - " Ale gdzie , że w to nie zaje . Nie miał za nas bez jednej strony Bo w nim , na nich bez siebie , Teraz się na to nie chciał Nie tak z niebios , że nie ma jego nie chce . Że rzecz się pan Horeszków nie miał . I to co się z nim nie mogła , " Więc Sędzia w polu , jak kto w zamku w karczmy Tak był , że nam wkoło jest , w Litwie : I nie jest w tej ziemi , i to nie było : Zazwą w ręku , na nim w tej bitwie . I po co ? to i już nie jest ? I z tej mej rodzinie już już o tym , I sam Sędzia . Ja nie może w niej zabrał , W połowie nie było , że on był rozpuszcza . Na Litwie , że się nie mógł Z jego boku , w tym z pomocą jego pomięcić , I tak się nie był w domu , z drugiej strony I potem , jeśli z kolei , że jego nie zmęty I sam na tyle
# ---------------------------
#
#
# --- Generated text after epoch 19.0:
# Jam jest Jacek Za tym swej nie miał ich za nim się wyrzekł Gdy się , jak w domu , a w tym się nie dawał . Czy to , z drugiej strony , w las i do siebie , Po tej nieprzyjaciel , gdy w środku ; I tam z wolna w polu , a w niej , z głowy , Tak nagle , jak gdyby nie na niebie , W której nie mógł się nie zatrąciła i nie wiedział , A tak było tak się na czele , Po co mnie uszły o tym nie podoba ; Poprawiano na Litwie w polu , i przeczuli się od czasu , Uciekał się , jak gdyby w niedawna Na końcu , jak gdyby się to nie dowiedział . Nie mogę na to w takim nim i nie będzie . To tam nie mogę ! Ale on , że był od lat tak się na co ? Że w powiecie , że się nie mógł czasu , jak od dzieciństwa , Bo z sobą się wkoło się na to nie mogę ? Z tej chwili ? - bo się będzie , kto sam w całym świecie I tam się tam w niezgodzie , i z których w świecie , Za tym na tyle ! " Na Litwie , w połowie się z wolna , Wyskoczył , że na koniec w izbie . Na znak . - i ja , co się
# ---------------------------
#
#
# --- Generated text after epoch 20.0:
# Jam jest Jacek Wyszukował i sam , bo to już to to niebym , " Za co " - rzekła Maćku - ja za moim wolą ! Bo to to , tak to ? " I to to z tobą ? ... " To by się , w tym Soplicczyna ! " I wszyscy nie będzie ! " - rzekł Hrabia - z tabapania Z Soplica ! - na to ksiądz Hrabia - czy pan Wojski , A ja za co ? " Sędzia , i już mi to tak miał Jak na co - do niego nie było , i że zrządziliśmy w takim świecie , Uadnie się , jak on ? w tym chwili Wpadłem i na tym ? Co ? - zawołał Sędzia - to w domu ! " Że po co , co mnie tam w tym nie będzie , Tak nie wiesz , czy ja w mieście ? co ! Co to to nie nie ! " A Pan Ojczywa ! - zawołał Klucznik ! " A to ja ! " I nie kto się , kto się zapił ! " Że więc ja o nim pan , a nie miał I po co się to nie miał Za ich rzecz za broń ! " Lecz to - rzekł Rejent , pan Sędzia , Lecz do nas ! ja nie mogłem w tym nim ...
# ---------------------------
#
#
# --- Generated text after epoch 21.0:
# Jam jest Jacek Jako gdyby milczący , co się uprawiwszy się na ziemi : Już go już w niebios ubiegły , I już już na to słowo Nie było , że ja , a kto nie będzie , I to był człowiek , nie wiedział , czy nie mogę I nie tak długo nie ma . A cóż się nie wie , jak to w tym nie było : Na miejscu w Litwie , który człek w tym niepocieny , Jak do nas zabawił , a tylko jego podłuciły się w tym kraju A w tym niebios , że na to rzecz to po co ? I tak nie , gdzie , to tylko nigdy nie ma ? I to był tu w powiecie nie może ? " Na nim z przodu ; to jest rzecz tyle ! " Więc pan Sędzio , co ? to nie mam - Tak sam z Rejent był w domu , i gdy się zażył , A więc w tym nie chce się nie będzie , I już nie było z dala Nie wiem , gdzie z których do domu i w niebo porywa . Na zawsze , bo to wyjął do zamku , A to to nie miał zwyczaju : Ja tu nie będzie . A to ? " A on rzekł : " " Po tym ? " -
# ---------------------------
#
#
# --- Generated text after epoch 22.0:
# Jam jest Jacek Lecz w domu , a on był na tym nie ... " I już znowu to był to gdzie ? Pogląda się , z niej , w całym jego wieku . I na tyle się nie tylko nie miał Że gdyby się nie wiem i jak jak szabli nie dożywali ! Gdy też z jego dom mu zabawiały się z dala . Zjąwszy się nie z rzadków i nieprędko na miejsce w polu . Lecz i dziś nie mógł dawno , i wszyscy się za ich nie wyśmiał . A potem się nie był był , ale w końcu zapił ; O tym w tym jak gdyby na tym nie mogę , Po co by był to tyle A gdy się w której jest to nie znał : Bo w tym nie był ? że nie mógł ! Nie widział i teraz nie jest na to ! W którym niedawne nie był to rzecz był i dziś jak na tyle się pocięwszy , I sam , że mu nie jest dziś zszedł : Po co to zająwszy głową : " Bracie ? " - rzekł Hrabia , pan Sędzia , Nie mogłem , czy co się że jest ? Nie tak nie może tylko z tego ... " Zmyśliłem , że nie jest ? Kto to nie wyrzekł , On go nie mógł
# ---------------------------
#
#
# --- Generated text after epoch 23.0:
# Jam jest Jacek Tak zwów na ziemię , czy się w zamku był w tym myśliły : W izbie pojął go , że go to do tego swym szlachcice Jak to tak jest w tym nie może ! A kiedy się o której sam nie będzie , Tak tak na świecie , że w świecie , z tych strony i na ziemi Uszła w całym , i gdy to z boku broni . Bo mój to nie mógł nie mogłem , bo ksiądz Hrabia mu nie w kraju ; Poprawiłem , nie nie tak się nie zapomać ; W oczach jego na nich się nie ma ; Jak już nie mogę Wkoło go nie mógł Uciekał , ale nie zna i zawsze nie ma ! Zajechał na Litwie , że go za czym , czy po nim za każdym strzelca mu Że ten to rzecz nie widział . Porządując na ziemi , jak i nieradszy , Że nie będzie przed panem Telimena , Co w niebios i niebios nie chciał ? Ale o cóż nam tam nie może Uciekał się , że go zalękła dla mnie , Nie będzie . Ja tak . Wojski był w takim swym rękę do swego , Tak nie była w takiej śmierci : to nie wkoło ich rzecz jedyna ,
# ---------------------------
#
#
# --- Generated text after epoch 24.0:
# Jam jest Jacek Tak w niej nieprzyjemne smuty , " Na nich w domu i w pole . I ten w oczach Horeszków rozprawiał na czele , Ale sam się w nocy , a tu się ubrzone i w tył : Wyszedł w połowie się na czele : Wprzód z wierzchu , na pole i pczecze . Oddziewał się , że go nie był bez władzy Aż w izbie jego z nim jak w górę i krewna , Wkoło się zawiązać jak grzywy , a z lewej tej niemożny I w pole I gdy w miejscu wkoło ich jak na środku . " Ale po co ? " Nie było - rzekł Tadeuszu , choć z panem Wojski . " Dejtań ; ten Hrabia z Woźny przyjeżdżał , Podkomorzy , lecz w mieście . Bo kiedy sam to w polu na Hrabię w trawie . I więc już mu mu miał nie mogę Zosi , w czasie : choć ja był z nim , Płuta na pole , a na końcu nie ma się urzekł : Tak było , że w świecie , w kraju i witazy I był też za to rzecz tak był Na świat do świata , i w gospodarstwie , I na ziemi i
# ---------------------------
#
#
# --- Generated text after epoch 25.0:
# Jam jest Jacek Że on to tak był dziś na świecie : Nie może mnie dziś nie było , że tylko tyle , W każdym gdyby się zajeżdżał , Nie chcesz z tej głębi jak nie w nocy : a w tej mocy , A on to z tej mocy poziełem Wszerzał się i w domu nie chce , tak wiele , A nie było ; potem i nie będzie , I nie wiedział , że kto tam nie jest : Uszedł z głową , bo ja to nie bez pamięci , Zająwszy się , że mu tak dobrze nie przeszkadza ; Bo z głową w oczach nie jest na to rzecz , I tak się nie będzie , że się będzie i za nim wkoło nie Nie tyle , że tam z daleka . Wyszedł do domu , aby się na wpół się miał Wybrał się , jak gdyby z daleka , I w czasie od rana . Bo tam w tym której za okiem zabiegł . Bo to nie było , że się uprawiano , On też , kiedy teraz , to rzecz na to Tadeusz nie było . Na nim nie muszę tylko pobiegłych i już wwał się uszedł ; Potem się tak chybiał , lecz miał się wystąpił , To nie wyrzekł ; nie mógł się w tym nie gadali . Lecz
# ---------------------------
# There were missing keys in the checkpoint model loaded: ['lm_head.decoder.weight', 'lm_head.decoder.bias'].
# TrainOutput(global_step=700, training_loss=5.332032470703125, metrics={'train_runtime': 1193.0589, 'train_samples_per_second': 4.568, 'train_steps_per_second': 0.587, 'total_flos': 1434801713971200.0, 'train_loss': 5.332032470703125, 'epoch': 25.0})
